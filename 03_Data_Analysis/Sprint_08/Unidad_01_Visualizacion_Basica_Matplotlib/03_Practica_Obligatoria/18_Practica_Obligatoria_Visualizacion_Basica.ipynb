# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: **Visualización Básica**

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un único ejercicio de construcción de gráficas. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# #### #1.1
#
# - Carga el dataset de casas de California que está en la ruta "./data/california_cities.csv".
# - Muestra parte de su contenido y su descripción.
# - Deshazte de las filas con nulos.

# %%
# Cargar dataset
df = pd.read_csv("./data/california_cities.csv",index_col=0)

# %%
# Mostrar primeras filas
print("Primeras filas del dataset:")
display(df.head())
# Out:
# Primeras filas del dataset:
#           city       latd       longd  elevation_m  elevation_ft  \
# 0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2      Alameda  37.756111 -122.274444          NaN          33.0
# 3       Albany  37.886944 -122.297778          NaN          43.0
# 4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# ...

# %%
# Mostrar información general
print("\nDescripción del dataset:")
display(df.describe(include="all"))
# Out:
# Descripción del dataset:
#             city        latd       longd  elevation_m  elevation_ft  \
# count        482  482.000000  482.000000   434.000000    470.000000
# unique       482         NaN         NaN          NaN           NaN
# top     Adelanto         NaN         NaN          NaN           NaN
# freq           1         NaN         NaN          NaN           NaN
# mean         NaN   36.095088 -119.837714   180.416705    567.168723
# std          NaN    2.298006    2.147676   309.531825   1001.265722
# min          NaN   32.578333 -124.263333   -34.000000   -180.000000
# 25%          NaN   33.977292 -121.954931    22.000000     69.000000
# 50%          NaN   36.204722 -119.708611    67.000000    200.000000
# 75%          NaN   37.886667 -117.977292   173.500000    515.000000
# max          NaN   41.965000 -114.596389  2402.000000   7880.000000
#
#         population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 482 entries, 0 to 481
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                482 non-null    object
#  1   latd                482 non-null    float64
#  2   longd               482 non-null    float64
#  3   elevation_m         434 non-null    float64
#  4   elevation_ft        470 non-null    float64
#  5   population_total    482 non-null    int64
#  6   area_total_sq_mi    480 non-null    float64
#  7   area_land_sq_mi     482 non-null    float64
#  8   area_water_sq_mi    481 non-null    float64
#  9   area_total_km2      477 non-null    float64
#  10  area_land_km2       478 non-null    float64
#  11  area_water_km2      478 non-null    float64
#  12  area_water_percent  477 non-null    float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 52.7+ KB

# %%
# Revisar cuántos nulos hay
print("\nValores nulos por columna:")
display(df.isnull().sum())

# Eliminar filas con nulos
df_clean = df.dropna()

print("\nTamaño después de eliminar nulos:", df_clean.shape)
df_clean.head()
# Out:
# Valores nulos por columna:
# city                   0
# latd                   0
# longd                  0
# elevation_m           48
# elevation_ft          12
# population_total       0
# area_total_sq_mi       2
# area_land_sq_mi        0
# area_water_sq_mi       1
# area_total_km2         5
# area_land_km2          4
# area_water_km2         4
# area_water_percent     5
# dtype: int64
# Tamaño después de eliminar nulos: (427, 13)
#           city       latd       longd  elevation_m  elevation_ft  \
# 0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 4     Alhambra  34.081944 -118.135000        150.0         492.0
# 5   AlisoViejo  33.575000 -117.725556        127.0         417.0
# 6      Alturas  41.487222 -120.542500       1332.0        4370.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 427 entries, 0 to 481
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                427 non-null    object
#  1   latd                427 non-null    float64
#  2   longd               427 non-null    float64
#  3   elevation_m         427 non-null    float64
#  4   elevation_ft        427 non-null    float64
#  5   population_total    427 non-null    int64
#  6   area_total_sq_mi    427 non-null    float64
#  7   area_land_sq_mi     427 non-null    float64
#  8   area_water_sq_mi    427 non-null    float64
#  9   area_total_km2      427 non-null    float64
#  10  area_land_km2       427 non-null    float64
#  11  area_water_km2      427 non-null    float64
#  12  area_water_percent  427 non-null    float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 46.7+ KB

# %% [markdown]
# #### #1.2
#
# Recrea la siguiente figura, para ello construye en apartados separados cada gráfico y luego haz un apartado en el que se junten los cuatro.
#
# Las figuras son:
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center"). (Colores: azul, gris, aceituna, marrón, con trasparencia)
#
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Bradley Hand ITC", tamaño 18, color azul acero o "steelblue")
# 3. El scatter de área de agua de un ciudad con su poblacion.
# 4. El boxplot de la altura de las ciudades.

# %% [markdown]
# ![figura_ejempo.png](attachment:figura_ejempo.png)

# %% [markdown]
# #### #1.3
#
# Graba la figura en un archivo .png y sube el archivo a tu repositorio personal junto con el notebook.

# %% [markdown]
# #1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center"). (Colores: azul, gris, aceituna, marrón, con trasparencia)

# %%
def separa_nombre(nombre):
    nuevo = nombre[0]
    for letra in nombre[1:]:
        if letra == letra.upper():
            nuevo += " "
        nuevo += letra
    return nuevo

# %%
# CODIGO RODRI
def separa_nombre(nombre):
    nuevo = nombre[0]
    for letra in nombre[1:]:
        if letra == letra.upper():
            nuevo += " "
        nuevo += letra
    return nuevo

ciudades_mas_pobladas = df.loc[df.population_total.nlargest(5).index, ["city","population_total"]]
ciudades = [separa_nombre(ciudad) for ciudad in ciudades_mas_pobladas["city"].to_list()]
colores = ["blue","gray","red","olive","brown"]
plt.figure(figsize = (8,5))
plt.bar(x= ciudades,
        height= ciudades_mas_pobladas["population_total"]/1000,
        color= colores,
        alpha= 0.5)
plt.ylim([0,5000])
plt.ylabel("Habitantes (miles)")
plt.xlabel("Ciudades")
plt.title("Ciudades más pobladas de California")
ciudades_mas_pobladas.set_index("city", inplace = True)
for indice, ciudad in enumerate(ciudades_mas_pobladas.index):
    poblacion = ciudades_mas_pobladas.loc[ciudad, "population_total"]/1000
    plt.text(ciudades[indice], poblacion + 100, f"{poblacion:.2f}", ha = "center")
plt.show()

# %%
# 1. Gráfico de barras — Ciudades más pobladas


import matplotlib.pyplot as plt
import numpy as np

# Seleccionar las 5 ciudades más pobladas
top5 = df_clean.nlargest(5, "population_total")

colors = ["blue", "gray", "violet", "brown", "lightgreen"]

# crea la figura y idbujar el grafico de barras
plt.figure(figsize=(8,6))                    
bars = plt.bar(top5["city"], top5["population_total"], color=colors, alpha=0.5)

# Agregar etiquetas encima de cada barra
for b in bars:
    height = b.get_height()
    plt.text(b.get_x() + b.get_width()/2, height + 20,
             f"{height:,.0f}", ha="center", fontsize=10)

# Agregar el titulo y las etiquetas
plt.title("Ciudades más pobladas de California", fontsize=15)
plt.ylabel("Habitantes (aprox.)")
plt.show()

# %% [markdown]
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Bradley Hand ITC", tamaño 18, color azul acero o "steelblue")

# %%
# # # Bradley Hand Itc en Legionfonts.com 
# # # https://legionfonts.com/fonts/bradley-hand-itc
# # # Para usar la fuente en Matplotlib hay que instalarla en su propio fontmanager
# # # Para encontrar la ruta a la carpeta de fuentes de Matplotib usar matplotlib.font_manager.findfont
import matplotlib
# matplotlib.font_manager.findfont('Bradley Hand Itc')
print(matplotlib.font_manager.findfont('Bradley Hand Itc'))
# Out:
# C:\Windows\Fonts\BRADHITC.TTF

# %%
# https://stackoverflow.com/questions/26085867/matplotlib-font-not-found
# Si la fuente está instalada en el gestor y Matplotlib no la detecta, entonces hay que borrar la caché
# Para encontrar la ruta de la caché usar print(matplotlib.get_cachedir())
# Borrar el json en la ruta indicada y reiniciar el cuaderno
import matplotlib
print(matplotlib.get_cachedir())
# Out:
# C:\Users\diana\.matplotlib

# %%
# CODIGO RODRI
plt.figure(figsize=(8,5))
plt.hist(df["area_total_km2"], 
         color = "steelblue", 
         alpha = 0.7, 
         bins = 50,
         label = "Hist Area")
plt.xlabel("Superficie ($km^2$)", fontdict = dict(family= "Bradley Hand ITC", size = 18))
plt.ylabel("Número de Ciudades", fontdict= dict(family = "Bradley Hand ITC", size = 18))
plt.legend()
plt.show()

# %%
# 2 Histograma — Área total ocupada por las ciudades

# crea un lienzo o espacio donde irá el grafico
plt.figure(figsize=(8,6))

# dibujar el histograma
plt.hist(df_clean["area_total_km2"],  # datos que queremos graficar
          bins=50, color="steelblue", # divide los datos en 50 grupos, mas bins,mas finas, steelblue color interno de la barras
            edgecolor="black", alpha=0.8)  # color del borde las barrras con el 0.8 que controla la transparencia
plt.title("Histograma del área total ocupada por las ciudades", fontsize=15)  # Añadir titulo
plt.xlabel("Superficie (km²)") # Etiquetas de los ejes
plt.ylabel("Número de Ciudades")
plt.legend(["Hist Area"])   # Agrega leyendas

plt.show()  # muestra el grafico

# %% [markdown]
# 3. El scatter de área de agua de un ciudad con su poblacion.

# %%
plt.figure(figsize=(8,5))
plt.scatter(x= df["area_water_km2"],
            y= df["population_total"]/1000,
            alpha= 0.5,
            color="green")
plt.xlabel("Área de agua en la ciudad ($km^2$)")
plt.ylabel("Población (miles habitantes)")
plt.title("Población por kilometro cuadrado de agua")
outlier_1_y = (df["population_total"]).nlargest(2).iloc[0]
outlier_2_y = (df["population_total"]).nlargest(2).iloc[1]
outlier_1_x = df.loc[df.population_total == outlier_1_y ,"area_water_km2"].values[0]
outlier_2_x = df.loc[df.population_total == outlier_2_y ,"area_water_km2"].values[0]
xytext = (65, 3000)
text = "Outliers"
plt.annotate(xy= (outlier_1_x, outlier_1_y/1000),
             xytext= xytext,
             text= text,
             arrowprops= dict(arrowstyle = "->"))
plt.annotate(xy= (outlier_2_x, outlier_2_y/1000),
             xytext= xytext,
             text= " " * len(text),
             arrowprops= dict(arrowstyle = "->"))
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,7))

# --- Scatter general ---
plt.scatter(
    df_clean["area_water_km2"],
    df_clean["population_total"],
    color="green",
    alpha=0.6,
    s=35
)

plt.title("Población por kilómetro cuadrado de agua", fontsize=14)
plt.xlabel("Área de agua en la ciudad ($km^2$)", fontsize=12)
plt.ylabel("Población total aproximadamente", fontsize=12)

# --- Outliers según tu gráfico ---
out1 = (90, 3900)
out2 = (122, 1350)

# Dibujar puntos outliers
plt.scatter(*out1, color="green", s=10)
plt.scatter(*out2, color="green", s=30)

# Texto "Outliers"
px, py = 78, 3500
plt.text(px, py, "Outliers", ha='center', va='center')


# Flechas
plt.annotate("", xy=out1, xytext=(px, py), arrowprops=dict(arrowstyle="->"))
plt.annotate("", xy=out2, xytext=(px, py), arrowprops=dict(arrowstyle="->"))


plt.show()

# %% [markdown]
# 4. El boxplot de la altura de las ciudades.

# %%
# 4. Boxplot — Altitud de las ciudades
plt.figure(figsize=(10,6))  # abrimos un lienzo para dibujar

# Creamos el boxplot
box = plt.boxplot(df_clean["elevation_m"],  # la columna que contiene la altitud de cada ciudad
                  vert=False,   # hace el boxplot horizontal
                  patch_artist=True,  # permite rellenar la caja con color
# Colores y estilos
                  boxprops=dict(facecolor="red", color="black"),
                  medianprops=dict(color="black"),
                  whiskerprops=dict(color="black"),
                  capprops=dict(color="black"),
                  flierprops=dict(marker='o', markersize=5))

plt.title("Diagrama de caja de la Altitud de las ciudades de California")
plt.ylabel("Altitud (m)")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv("./data/california_cities.csv")
df_clean = df.dropna()   # quitar filas con nulos

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# 1) Barras: 5 ciudades más pobladas
ax = axs[0, 0]

top5 = df_clean.nlargest(5, "population_total")

colors = ["blue", "gray", "violet", "brown", "lightgreen"]

bars = ax.bar(top5["city"], top5["population_total"], color=colors)

# Etiquetas numéricas encima de cada barra
for b in bars:
    x = b.get_x() + b.get_width() / 2
    y = b.get_height()
    ax.text(x, y + 50, f"{y:.0f}", ha="center", va="bottom", fontsize=9)

ax.set_title("Ciudades más pobladas de California", fontsize=13)
ax.set_ylabel("Habitantes (aprox.)", fontsize=11)
ax.tick_params(axis='x', rotation=45)

# 2) Histograma área total ocupada
ax = axs[0, 1]

ax.hist(
    df_clean["area_total_km2"],
    bins=50,
    color="steelblue",
    edgecolor="black",
    alpha=0.8,
    label="Hist Area"
)

ax.set_title(
    "Histograma del área total ocupada por las ciudades",
    fontsize=15,
    fontname="Bradley Hand ITC"  # si la fuente no existe, usa la por defecto
)
ax.set_xlabel("Superficie (km²)", fontsize=11)
ax.set_ylabel("Número de Ciudades", fontsize=11)
ax.legend()

# 3) Scatter: área de agua vs población
ax = axs[1, 0]

ax.scatter(
    df_clean["area_water_km2"],
    df_clean["population_total"],
    color="green",
    alpha=0.6,
    s=35
)

ax.set_title("Población por kilómetro cuadrado de agua", fontsize=13)
ax.set_xlabel("Área de agua en la ciudad ($km^2$)", fontsize=11)
ax.set_ylabel("Población total aproximadamente", fontsize=11)

# Outliers (aproximados según la figura de ejemplo)
out1 = (90, 3900)
out2 = (122, 1350)

ax.scatter(*out1, color="green", s=50)
ax.scatter(*out2, color="green", s=50)

# Texto "Outliers"
px, py = 75, 3450
ax.text(px, py, "Outliers")

# Flechas hacia los outliers
ax.annotate("", xy=out1, xytext=(px, py),
            arrowprops=dict(arrowstyle="->"))
ax.annotate("", xy=out2, xytext=(px, py),
            arrowprops=dict(arrowstyle="->"))

# 4) Boxplot horizontal de la altitud
ax = axs[1, 1]

ax.boxplot(
    df_clean["elevation_m"],
    vert=False,           # horizontal
    patch_artist=True,
    boxprops=dict(facecolor="red", color="black"),
    medianprops=dict(color="black"),
    whiskerprops=dict(color="black"),
    capprops=dict(color="black"),
    flierprops=dict(marker='o', markerfacecolor='black', markersize=5)
)

ax.set_title("Diagrama de caja de la Altitud de las ciudades de California")
ax.set_xlabel("Altitud (m)")

# Ajustar espacios para que no se solapen
plt.tight_layout()
plt.savefig("figura_ejercicio.png", dpi=300, bbox_inches="tight")
plt.show()
